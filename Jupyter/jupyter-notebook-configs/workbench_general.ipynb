# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
# svg, png. no inline pdf.

# %%
# viz
import matplotlib as mpl
import matplotlib.pyplot as plt
#import seaborn as sns

# analytics
import numpy as np
import scipy
import scipy.stats
import sklearn
import pandas as pd

# dates
import datetime
import dateutil
import dateutil.parser

# i/o
import cPickle as pickle
import unicodecsv as csv
import json
import re
import sqlite3

# utils
import os
import sys
import collections
from pprint import pprint

# %%
# NLP
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import SnowballStemmer
import string
import nltk
import re

# %%
# numerical config
np.seterr(divide='raise', over='raise', under='raise', invalid='raise');

# %%
# plot config
plt.style.use('ggplot')
mpl.rc('font', size=10)
mpl.rc('savefig', dpi=500, format='pdf', bbox='tight')
mpl.rc('axes', labelsize='medium', titlesize='medium')
mpl.rc('legend', fontsize='medium', framealpha=0.95)

mpl.rcParams['figure.autolayout'] = True
    # May trigger warning for some plotting extensions:
    # This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
    # otherwise manually call with: plt.tight_layout()

# %% [markdown]
# # Misc.

# %%
#plt.style.available
#[u'dark_background', u'bmh', u'grayscale', u'ggplot', u'fivethirtyeight']

# %% [markdown]
# # Work

# %%
fig, ax = plt.subplots(1, 1)

vals = np.random.normal(loc=100.0, scale=15, size=5000)
ser = pd.Series(vals)
ser.plot.hist(bins=30, ax=ax, label='bar')

x = np.linspace(60, 140)
y = np.power(x-60, 1.4)
ser = pd.Series(index=x, data=y)
ser.plot.line(ax=ax, label='foo')

ax.set_xlabel('Foobar Quotient')
ax.set_ylabel('Frequency')
ax.set_title("""A random sample drawn from a normal distribution
with another line superimposed on top
and also a long title that spans three lines""")
ax.legend(loc='lower right')

fig.savefig('test_figure')
# Out:
# /Volumes/SamsungSSD/Users/matt/Academia/Research/RESEARCH_WORK_Exeter/UoE-BlackSwan-Nestedness/Codebase/venv/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
